# %%
import pandas as pd
from pandas import Series, DataFrame
import numpy as np

# %%
data = pd.read_csv('MassOrder-157.csv')

# %%
data
# Out:
#    Order Name                             Email  \
# 0      #57569        Samanthatyfair82@gmail.com
# 1      #57568       brendantryan@protonmail.com
# 2      #57568       brendantryan@protonmail.com
# 3      #57568       brendantryan@protonmail.com
# 4      #57568       brendantryan@protonmail.com
# 5      #57567          angelaporter59@gmail.com
# 6      #57567          angelaporter59@gmail.com
# 7      #57567          angelaporter59@gmail.com
# 8      #57567          angelaporter59@gmail.com
# 9      #57566                               NaN
# 10     #57565           andrewawa2022@gmail.com
# 11     #57564          angelaporter59@gmail.com
# 12     #57563          gabriellerulon@gmail.com
# 13     #57562  satterfielddmanagement@gmail.com
# 14     #57562  satterfielddmanagement@gmail.com
# 15     #57561          kennethadolfo@icloud.com
# 16     #57560          kennethadolfo@icloud.com
# 17     #57559                               NaN
# ...

# %%
#CHECK ALL ITEMS THERE

# %%
spotmonthly = data[data["Line Item Name (Product Title + Options)"].str.contains("Spotify Monthly Listeners")==True]

#bundles
ttbundle1 = data[data["Line Item Name (Product Title + Options)"].str.contains("TikTok Bundle: 250 Likes + 5K Views")==True]



#igsaves
instagramsaves = data[data["Line Item Name (Product Title + Options)"].str.contains("Instagram Saves")==True]





twittervideoviews = data[data["Line Item Name (Product Title + Options)"].str.contains("Twitter Video Views")==True]
twitterlikes = data[data["Line Item Name (Product Title + Options)"].str.contains("Twitter Likes")==True]
twitterfollowers = data[data["Line Item Name (Product Title + Options)"].str.contains("Twitter Followers")==True]
twitterretweets = data[data["Line Item Name (Product Title + Options)"].str.contains("Twitter Retweets")==True]

#youtube watch time
ytwatchtime = data[data["Line Item Name (Product Title + Options)"].str.contains("4K Hours - YouTube Watch Time")==True]



#twitch auto views
twitch100ten = data[data["Line Item Name (Product Title + Options)"].str.contains("100+ Twitch Live Views - 10 Minutes")==True]
twitch100thrty = data[data["Line Item Name (Product Title + Options)"].str.contains("100+ Twitch Live Views - 30 Minutes")==True]
twitch100sixty = data[data["Line Item Name (Product Title + Options)"].str.contains("100+ Twitch Live Views - 60 Minutes")==True]
twitch100eighty = data[data["Line Item Name (Product Title + Options)"].str.contains("100+ Twitch Live Views - 180 Minutes")==True]
twitch250ten = data[data["Line Item Name (Product Title + Options)"].str.contains("250+ Twitch Live Views - 10 Minutes")==True]
twitch250thirty = data[data["Line Item Name (Product Title + Options)"].str.contains("250+ Twitch Live Views - 30 Minutes")==True]
twitch250sixty = data[data["Line Item Name (Product Title + Options)"].str.contains("250+ Twitch Live Views - 60 Minutes")==True]
twitch250eighty = data[data["Line Item Name (Product Title + Options)"].str.contains("250+ Twitch Live Views - 180 Minutes")==True]


igviews = data[data["Line Item Name (Product Title + Options)"].str.contains("Instagram Views")==True]



igtvlikes = data[data["Line Item Name (Product Title + Options)"].str.contains("Instagram TV Likes")==True]
igtvviews = data[data["Line Item Name (Product Title + Options)"].str.contains("Instagram TV Views")==True]
igreellikes = data[data["Line Item Name (Product Title + Options)"].str.contains("Instagram Reel Likes")==True]
igreelviews = data[data["Line Item Name (Product Title + Options)"].str.contains("Instagram Reel Views")==True]

#igtv likes + views
#igreel likes + views

iglikes = data[data["Line Item Name (Product Title + Options)"].str.contains("Instagram Likes")==True]
ttlikes = data[data["Line Item Name (Product Title + Options)"].str.contains("TikTok Likes")==True]
ytviews = data[data["Line Item Name (Product Title + Options)"].str.contains("YouTube Views")==True]
twitchfollowers = data[data["Line Item Name (Product Title + Options)"].str.contains("Twitch Followers")==True]
ttviews = data[data["Line Item Name (Product Title + Options)"].str.contains("TikTok Views")==True]
ytlikes = data[data["Line Item Name (Product Title + Options)"].str.contains("YouTube Likes")==True]
igviews = data[data["Line Item Name (Product Title + Options)"].str.contains("Instagram Views")==True]
igfollowers = data[data["Line Item Name (Product Title + Options)"].str.contains("Instagram Followers")==True]
ytviews = data[data["Line Item Name (Product Title + Options)"].str.contains("YouTube Views")==True]
ttfollowers = data[data["Line Item Name (Product Title + Options)"].str.contains("TikTok Followers")==True]
soundcloudlikes = data[data["Line Item Name (Product Title + Options)"].str.contains("SoundCloud Likes")==True]
soundcloudplays = data[data["Line Item Name (Product Title + Options)"].str.contains("SoundCloud Plays")==True]
soundcloudfollowers = data[data["Line Item Name (Product Title + Options)"].str.contains("SoundCloud Followers")==True]
spotifyplays = data[data["Line Item Name (Product Title + Options)"].str.contains("Spotify Plays")==True]
spotifyartistfollowers = data[data["Line Item Name (Product Title + Options)"].str.contains("Spotify Artist Followers")==True]
spotifyplaylistfollowers = data[data["Line Item Name (Product Title + Options)"].str.contains("Spotify Playlist Followers")==True]
twitchlive = data[data["Line Item Name (Product Title + Options)"].str.contains("Twitch Live")==True]
#Bundles
ttbundle1 = data[data["Line Item Name (Product Title + Options)"].str.contains("TikTok Bundle - 100 Likes, 25K Views")==True]

# %%
ytwatchtime
# Out:
# Empty DataFrame
# Columns: [Order Name, Email, Line Item Name (Product Title + Options), Order Line item Properties 1 Value, Transaction Date (Created), Order Item Quantity, Billing Phone]
# Index: []

# %%
#spotmonth
spotmonthlymass = spotmonthly[['Order Line item Properties 1 Value', 'Order Item Quantity','Line Item Name (Product Title + Options)' ]].copy()

#bundle
ttbundle1mass = ttbundle1[['Order Line item Properties 1 Value', 'Order Item Quantity','Line Item Name (Product Title + Options)' ]].copy()


instagramsavesmass = instagramsaves[['Order Line item Properties 1 Value', 'Order Item Quantity','Line Item Name (Product Title + Options)' ]].copy()

ytwatchtimemass = ytwatchtime[['Order Line item Properties 1 Value', 'Order Item Quantity','Line Item Name (Product Title + Options)' ]].copy()



twittervideoviewsmass = twittervideoviews[['Order Line item Properties 1 Value', 'Order Item Quantity','Line Item Name (Product Title + Options)' ]].copy()
twitterlikesmass = twitterlikes[['Order Line item Properties 1 Value', 'Order Item Quantity','Line Item Name (Product Title + Options)' ]].copy()
twitterfollowersmass = twitterfollowers[['Order Line item Properties 1 Value', 'Order Item Quantity','Line Item Name (Product Title + Options)' ]].copy()
twitterretweetsmass = twitterretweets[['Order Line item Properties 1 Value', 'Order Item Quantity','Line Item Name (Product Title + Options)' ]].copy()

igtvlikesmass = igtvlikes[['Order Line item Properties 1 Value', 'Order Item Quantity','Line Item Name (Product Title + Options)' ]].copy()
igtvviewsmass = igtvviews[['Order Line item Properties 1 Value', 'Order Item Quantity','Line Item Name (Product Title + Options)' ]].copy()
igreellikesmass = igreellikes[['Order Line item Properties 1 Value', 'Order Item Quantity','Line Item Name (Product Title + Options)' ]].copy()
igreelviewsmass = igreelviews[['Order Line item Properties 1 Value', 'Order Item Quantity','Line Item Name (Product Title + Options)' ]].copy()

#igtv likes + views
#igreel likes + views

#twitch
twitch100tenmass = twitch100ten[['Order Line item Properties 1 Value', 'Order Item Quantity','Line Item Name (Product Title + Options)' ]].copy()
twitch100thrtymass = twitch100thrty[['Order Line item Properties 1 Value', 'Order Item Quantity','Line Item Name (Product Title + Options)' ]].copy()
twitch100sixtymass = twitch100sixty[['Order Line item Properties 1 Value', 'Order Item Quantity','Line Item Name (Product Title + Options)' ]].copy()
twitch100eightymass = twitch100eighty[['Order Line item Properties 1 Value', 'Order Item Quantity','Line Item Name (Product Title + Options)' ]].copy()
twitch250tenmass = twitch250ten[['Order Line item Properties 1 Value', 'Order Item Quantity','Line Item Name (Product Title + Options)' ]].copy()
twitch250thirtymass = twitch250thirty[['Order Line item Properties 1 Value', 'Order Item Quantity','Line Item Name (Product Title + Options)' ]].copy()
twitch250sixtymass = twitch250sixty[['Order Line item Properties 1 Value', 'Order Item Quantity','Line Item Name (Product Title + Options)' ]].copy()
twitch250eightymass = twitch250eighty[['Order Line item Properties 1 Value', 'Order Item Quantity','Line Item Name (Product Title + Options)' ]].copy()

#IGviews
igviewsmass = igviews[['Order Line item Properties 1 Value', 'Order Item Quantity','Line Item Name (Product Title + Options)' ]].copy()



iglikesmass = iglikes[['Order Line item Properties 1 Value', 'Order Item Quantity','Line Item Name (Product Title + Options)' ]].copy()
igviewsmass = igviews[['Order Line item Properties 1 Value', 'Order Item Quantity','Line Item Name (Product Title + Options)' ]].copy()
igfollowersmass = igfollowers[['Order Line item Properties 1 Value', 'Order Item Quantity','Line Item Name (Product Title + Options)' ]].copy()
ytviewsmass = ytviews[['Order Line item Properties 1 Value', 'Order Item Quantity','Line Item Name (Product Title + Options)' ]].copy()
ytlikesmass = ytlikes[['Order Line item Properties 1 Value', 'Order Item Quantity','Line Item Name (Product Title + Options)' ]].copy()
ttlikesmass = ttlikes[['Order Line item Properties 1 Value', 'Order Item Quantity','Line Item Name (Product Title + Options)' ]].copy()
ttfollowersmass = ttfollowers[['Order Line item Properties 1 Value', 'Order Item Quantity','Line Item Name (Product Title + Options)' ]].copy()
twitchfollowersmass = twitchfollowers[['Order Line item Properties 1 Value', 'Order Item Quantity','Line Item Name (Product Title + Options)']].copy()
ttviewsmass = ttviews[['Order Line item Properties 1 Value', 'Order Item Quantity','Line Item Name (Product Title + Options)']].copy()
soundcloudlikesmass = soundcloudlikes[['Order Line item Properties 1 Value', 'Order Item Quantity','Line Item Name (Product Title + Options)']].copy()
soundcloudplaysmass = soundcloudplays[['Order Line item Properties 1 Value', 'Order Item Quantity','Line Item Name (Product Title + Options)']].copy()
soundcloudfollowersmass = soundcloudfollowers[['Order Line item Properties 1 Value', 'Order Item Quantity','Line Item Name (Product Title + Options)']].copy()
spotifyplaysmass = spotifyplays[['Order Line item Properties 1 Value', 'Order Item Quantity','Line Item Name (Product Title + Options)']].copy()
spotifyartistfollowersmass = spotifyartistfollowers[['Order Line item Properties 1 Value', 'Order Item Quantity','Line Item Name (Product Title + Options)']].copy()
spotifyplaylistfollowersmass = spotifyplaylistfollowers[['Order Line item Properties 1 Value', 'Order Item Quantity','Line Item Name (Product Title + Options)']].copy()
twitchlivemass = twitchlive[['Order Line item Properties 1 Value', 'Order Item Quantity','Line Item Name (Product Title + Options)']].copy()
#Bundles 
ttbundle1mass = ttbundle1[['Order Line item Properties 1 Value', 'Order Item Quantity','Line Item Name (Product Title + Options)']].copy()

# %%
ytwatchtimemass
# Out:
# Empty DataFrame
# Columns: [Order Line item Properties 1 Value, Order Item Quantity, Line Item Name (Product Title + Options)]
# Index: []

# %%
#if ttbundle1mass == True:
   # ttviews = (f'4314|{url}|25000')
   # ttlikes = (f'2423|{url}|125')

# %%
#spotmonthmass
spotmonthlymass.insert(0,'ID',"1244")

#bundle
ttbundle1mass.insert(0,'ID',"1233")

instagramsavesmass.insert(0,'ID',"1233")

ytwatchtimemass.insert(0,'ID',"1225")

#twitch
twitch100tenmass.insert(0,'ID',"1194|")
twitch100thrtymass.insert(0,'ID',"1195|")
twitch100sixtymass.insert(0,'ID',"1196|")
twitch100eightymass.insert(0,'ID',"1197|")
twitch250tenmass.insert(0,'ID',"1194|")
twitch250thirtymass.insert(0,'ID',"1195|")
twitch250sixtymass.insert(0,'ID',"1196|")
twitch250eightymass.insert(0,'ID',"1197|")

#igviewsmass.insert(0,'ID',"1214|")

twittervideoviewsmass.insert(0,'ID',"1052|")
twitterlikesmass.insert(0,'ID',"1283|")
twitterfollowersmass.insert(0,'ID',"1282|")
twitterretweetsmass.insert(0,'ID',"1102|")
    
iglikesmass.insert(0,'ID',"1015|")
igviewsmass.insert(0,'ID',"1313|")
igfollowersmass.insert(0,'ID',"1155|")
ytviewsmass.insert(0,'ID',"1315|")
ytlikesmass.insert(0,'ID',"1305|")
ttlikesmass.insert(0,'ID',"1308|")
ttviewsmass.insert(0,'ID',"1304|")
    #SCLIKESFIX
soundcloudlikesmass.insert(0,'ID',"1261|")
soundcloudplaysmass.insert(0,'ID',"1130|")
soundcloudfollowersmass.insert(0,'ID',"1267|")
spotifyplaysmass.insert(0,'ID',"1228|")
spotifyartistfollowersmass.insert(0,'ID',"1128|")
spotifyplaylistfollowersmass.insert(0,'ID',"1219|")
twitchfollowers.insert(0,'ID',"991|")
ttfollowersmass.insert(0,'ID',"1285|")
    #twitchlivemass.insert(0,'ID',"1027")
    #NEW
igtvlikesmass.insert(0,'ID',"1097|")
igtvviewsmass.insert(0,'ID',"1104|")
igreellikesmass.insert(0,'ID',"1096|")
igreelviewsmass.insert(0,'ID',"1095|")

# %%
ytwatchtimemass
# Out:
# Empty DataFrame
# Columns: [ID, Order Line item Properties 1 Value, Order Item Quantity, Line Item Name (Product Title + Options)]
# Index: []

# %%
iglikesmass
twitchfollowers
ytviewsmass
#APPEND ALL Below # (ID RESTART fyi)
final = iglikesmass.append([iglikesmass, igviewsmass, igfollowersmass, ytviewsmass, ytlikesmass, ttlikesmass, ttviewsmass, soundcloudlikesmass, soundcloudplaysmass, soundcloudfollowersmass, spotifyplaysmass, spotifyartistfollowersmass, spotifyplaylistfollowersmass, twitchfollowers, ttfollowersmass, twitchlivemass, igtvlikesmass, igtvviewsmass, igreellikesmass, igreelviewsmass, ytwatchtimemass,spotmonthlymass])

# %%
final
# Out:
#        ID                 Order Line item Properties 1 Value  \
# 2   1015|  https://www.instagram.com/reel/Ck9ZYR_OY-F/?ut...
# 9   1015|  https://www.instagram.com/p/Ck9E20LSUMf/?igshi...
# 12  1015|               https://instagram.com/p/Cj32VKGvSNA/
# 14  1015|  https://www.instagram.com/p/CioW8Y_sJfH/?igshi...
# 21  1015|  https://www.instagram.com/reel/Ck8aNkUvCqR/?ig...
# 23  1015|  https://www.instagram.com/reel/Ck8sEVqpd5b/?ig...
# 27  1015|         https://www.instagram.com/reel/Ck8Wimkv20a
# 2   1015|  https://www.instagram.com/reel/Ck9ZYR_OY-F/?ut...
# 9   1015|  https://www.instagram.com/p/Ck9E20LSUMf/?igshi...
# 12  1015|               https://instagram.com/p/Cj32VKGvSNA/
# 14  1015|  https://www.instagram.com/p/CioW8Y_sJfH/?igshi...
# 21  1015|  https://www.instagram.com/reel/Ck8aNkUvCqR/?ig...
# 23  1015|  https://www.instagram.com/reel/Ck8sEVqpd5b/?ig...
# 27  1015|         https://www.instagram.com/reel/Ck8Wimkv20a
# ...

# %%
final['QTY'] = final['Line Item Name (Product Title + Options)'].str.replace('K','000')

# %%
#not tested with 1M option yet
final['QTY'] = final['QTY'].str.replace('M','000000')

# %%
#final

# %%
#QTY COLUMN ONLY NUMBERS
final['QTY'] = final['QTY'].str.extract('(\d+)')

# %%
#final

# %%
#set columns to integers
final["QTY"] = final["QTY"].astype(float)
final["Order Item Quantity"] = final["Order Item Quantity"].astype(float)

# %%
#multiply qty by Order Item Quantity

# %%
final["finalqty"] = final["QTY"] * final["Order Item Quantity"] * 1.2

# %%
#converts to integer 
final["finalqty"] = final["finalqty"].astype(int)

# %%
del final['Order Item Quantity']
del final['Line Item Name (Product Title + Options)']
del final['Email']
del final['Transaction Date (Created)']
del final['Billing Phone']
del final['QTY']
del final['Order Name']

# %%
final['finalqty'] = '|' + final['finalqty'].astype(str)

# %%
final
# Out:
#        ID                 Order Line item Properties 1 Value finalqty
# 2   1015|  https://www.instagram.com/reel/Ck9ZYR_OY-F/?ut...     |180
# 9   1015|  https://www.instagram.com/p/Ck9E20LSUMf/?igshi...     |180
# 12  1015|               https://instagram.com/p/Cj32VKGvSNA/    |1200
# 14  1015|  https://www.instagram.com/p/CioW8Y_sJfH/?igshi...     |420
# 21  1015|  https://www.instagram.com/reel/Ck8aNkUvCqR/?ig...     |180
# 23  1015|  https://www.instagram.com/reel/Ck8sEVqpd5b/?ig...     |420
# 27  1015|         https://www.instagram.com/reel/Ck8Wimkv20a     |180
# 2   1015|  https://www.instagram.com/reel/Ck9ZYR_OY-F/?ut...     |180
# 9   1015|  https://www.instagram.com/p/Ck9E20LSUMf/?igshi...     |180
# 12  1015|               https://instagram.com/p/Cj32VKGvSNA/    |1200
# 14  1015|  https://www.instagram.com/p/CioW8Y_sJfH/?igshi...     |420
# 21  1015|  https://www.instagram.com/reel/Ck8aNkUvCqR/?ig...     |180
# ...

# %%
final.to_csv('6today-final.csv',index=False)

# %%
#massorder = single[single['URL'].notna()]
#massorder
